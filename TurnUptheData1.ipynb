# %%
# Dependencies
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import csv
import scipy.stats as st
from scipy.stats import linregress


# Import CSVs
artist_df = pd.read_csv('Resources/data_by_artist.csv')
genres_df = pd.read_csv('Resources/data_by_genres.csv')
year_df = pd.read_csv('Resources/data_by_year.csv')
with_genres_df = pd.read_csv('Resources/data_w_genres.csv')
overall_df = pd.read_csv('Resources/data.csv')

# %%
overall_df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
type(overall_df.year)
# Out:
# pandas.core.series.Series

# %%
overall_2019_df = overall_df[overall_df.year== 2017]
overall_2019_df
# Out:
#         acousticness                       artists  danceability  duration_ms  \
# 15879       0.001760                 ['Green Day']         0.206       144627
# 17315       0.923000                 ['Vera Lynn']         0.181       152787
# 18053       0.390000                   ['Proper.']         0.479       223343
# 18113       0.923000                 ['Vera Lynn']         0.181       152787
# 18371       0.211000                ['Paul Simon']         0.230       251400
# ...              ...                           ...           ...          ...
# 173648      0.715000           ['Jonathan Broady']         0.665       272555
# 173652      0.008500        ['Latin Sound Groove']         0.704       191967
# 173662      0.000056    ['Brain Devices', 'Aloom']         0.695       482232
# 173680      0.010400          ['CrossFit Junkies']         0.653       258601
# 173718      0.995000  ['Tranquility Spa Universe']         0.192       207000
#
# ...

# %%
overall_2019_df.describe()
# Out:
#        acousticness  danceability   duration_ms       energy     explicit  \
# count   2156.000000   2156.000000  2.156000e+03  2156.000000  2156.000000
# mean       0.207413      0.580475  2.434022e+05     0.686392     0.224490
# std        0.287968      0.183299  1.737090e+05     0.229292     0.417343
# min        0.000002      0.000000  3.259400e+04     0.000020     0.000000
# 25%        0.004548      0.475750  1.817142e+05     0.535750     0.000000
# 50%        0.056700      0.603500  2.162710e+05     0.720000     0.000000
# 75%        0.306250      0.718250  2.658102e+05     0.874000     0.000000
# max        0.996000      0.973000  3.897591e+06     1.000000     1.000000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2156.000000  2156.000000  2156.000000  2156.000000  2156.000000
# mean           0.247068     5.318182     0.231513    -8.026319     0.608998
# ...

# %%
overall_df.head(1)
# Out:
#    acousticness          artists  danceability  duration_ms  energy  explicit  \
# 0         0.991  ['Mamie Smith']         0.598       168333   0.224         0
#
#                        id  instrumentalness  key  liveness  loudness  mode  \
# 0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5     0.379   -12.628     0
#
#                        name  popularity release_date  speechiness    tempo  \
# 0  Keep A Song In Your Soul          12         1920       0.0936  149.976
#
#    valence  year
# 0    0.634  1920

# %%
years_1920to1930 = []
years_1931to1940 = []
years_1941to1950 = []
years_1951to1960 = []
years_1961to1970 = []
years_1971to1980 = []
years_1981to1990 = []
years_1991to2000 = []
years_2000to2010 = []
years_2011to2020 = []
year_2021 =[]
years = overall_df.year()

for i in years:
    if overall_df.year <2011 & overall_df.year>=2020:
        years_2011to2020.append()
    else:
        year_2021.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7541fb1dce55> in <module>
#      10 years_2011to2020 = []
#      11 year_2021 =[]
# ---> 12 years = overall_df.year()
#      13
#      14 for i in years:
#
# TypeError: 'Series' object is not callable

# %%
year2001_df = artist_df.loc[artist_df['year' == 2001]]
year1933to1939_df = artist_df.loc[(artist_df['year'] >=1933) &(artist_df['year'] <=1939)]
years1942to1945_df =artist_df.loc[(artist_df['year'] >=1942) &(artist_df['year'] <=1945)]
years2007to2008_df = artist_df.loc[(artist_df['year'] >=2007) &(artist_df['year'] <=2008)]
years1990to1992_df = artist_df.loc[(artist_df['year'] >=1990) &(artist_df['year'] <=1992)]
